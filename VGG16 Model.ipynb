# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.layers import Input, Concatenate, Dense, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2



seed = 123

np.random.seed(seed)
tf.random.set_seed(seed)

# Define the directory where the dataset is stored
dataset_dir = 'E:/modified_dataset'

# Define the image size and channels
img_size = (224, 224)
img_channels = 3

# Define the number of notes in the dataset
num_notes = len(os.listdir(os.path.join(dataset_dir, 'real_notes'))) + len(os.listdir(os.path.join(dataset_dir, 'fake_notes'))) 

# Define the VGG16 model with pre-trained weights
vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], img_channels))

def extract_features(dataset_dir, vgg16_model):
    features_list = []
    labels_list = []
    note_paths_list = []
    
    for class_dir in os.listdir(dataset_dir):
        if class_dir.startswith('.'):
            continue
        class_path = os.path.join(dataset_dir, class_dir)

        for note_dir in os.listdir(class_path):
            if note_dir.startswith('.'):
                continue
            note_path = os.path.join(class_path, note_dir)

            num_images_per_note = len([name for name in os.listdir(note_path) if os.path.isfile(os.path.join(note_path, name))])
            images = []

            for i in range(1, num_images_per_note + 1):
                image_path = os.path.join(note_path, f'note_{note_dir.split("_")[1]}_{i}.jpg')

                image = cv2.imread(image_path)
                image = cv2.resize(image, img_size)
                image = preprocess_input(image)
                images.append(image)

            features = vgg16_model.predict(np.array(images))
            features = features.reshape((1, num_images_per_note,  7, 7, 512))
            
            features_list.append(features)
            if class_dir == 'real_notes':
                labels_list.append(0)
            else:
                labels_list.append(1)
            
            note_paths_list.append(note_path)
    
    X = np.vstack(features_list)
    y = np.array(labels_list)
    
    return X, y, note_paths_list

X, y, note_paths = extract_features(dataset_dir, vgg16_model)


X_train, X_val_test, y_train, y_val_test, note_paths_train, note_paths_val_test = train_test_split(X, y, note_paths, test_size=0.4, random_state=seed)
X_val, X_test, y_val, y_test, note_paths_val, note_paths_test = train_test_split(X_val_test, y_val_test, note_paths_val_test, test_size=0.5, random_state=seed)



input_tensor = Input(shape=(X.shape[1],  7, 7, 512))

split_tensors = Lambda(lambda x: tf.unstack(x, axis=1))(input_tensor)
branches = [Flatten()(split_tensors[i]) for i in range(X.shape[1])]
concat = Concatenate()(branches)
dropout = Dropout(0.6)(concat)
fcnn = Dense(64, activation='relu', kernel_regularizer=l2(0.00005))(dropout)  # Added L2 regularization
fcnn = Dense(1, activation='sigmoid')(fcnn)
model = Model(inputs=input_tensor, outputs=fcnn)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


#Saving the best Model
# Define the directory where you want to save the best model
best_model_dir = 'E:/my_model'

# Create the directory if it does not exist
os.makedirs(best_model_dir, exist_ok=True)

# Define the ModelCheckpoint callback with the updated file path
best_model_file_path = os.path.join(best_model_dir, 'vgg16_model.h5')
checkpoint = ModelCheckpoint(best_model_file_path, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, mode='min', verbose=1)

history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), callbacks=[checkpoint, early_stopping])
# Import the necessary libraries
import matplotlib.pyplot as plt

# Plot the training and validation accuracy vs epoch
fig, ax = plt.subplots(figsize=(5, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy (Train and Validation) vs Epoch')
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss vs epoch
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (Train and Validation) vs Epoch')
plt.legend(loc='upper right')
plt.show()


# Load the best model saved by ModelCheckpoint
best_model = tf.keras.models.load_model(best_model_file_path)

test_loss, test_acc = best_model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_acc}")



# Evaluate the best model on the validation set
val_loss, val_acc = best_model.evaluate(X_val, y_val)
print(f"Validation loss: {val_loss}")
print(f"Validation accuracy: {val_acc}")




# Get the predicted labels
predictions = model.predict(X_test)
predicted_labels = (predictions > 0.5).astype(int)


# Function to convert numerical labels to string labels
def label_to_string(label):
    return "real" if label == 0 else "fake"

# Print the original labels, predicted labels, and note_paths for the test set
print("\n Note Path | Predicted Label | Original Label ")
print("-" * 45)
for original_label, predicted_label, note_path in zip(y_test, predicted_labels.flatten(), note_paths_test):
    print(f" {note_path} | {label_to_string(predicted_label)} | {label_to_string(original_label)}")

# Import the necessary libraries
from sklearn.metrics import confusion_matrix, classification_report

# Make predictions using the best model
y_pred = best_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(3, 3))
sns.heatmap(cm, annot=True, cmap='Blues', cbar=False, ax=ax , fmt='d')
ax.set_title('Confusion Matrix')
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
plt.show()



# Calculate and print precision, recall, and F1 score
precision = cm[1, 1] / (cm[1, 1] + cm[0, 1])
recall = cm[1, 1] / (cm[1, 1] + cm[1, 0])
f1 = 2 * precision * recall / (precision + recall)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 score: {f1:.2f}")

from sklearn.metrics import roc_curve, auc

# Make predictions using the best model and get probabilities
y_pred_probs = best_model.predict(X_test)

# Calculate the FPR, TPR, and threshold values
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)

# Calculate the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(3, 3))
plt.plot(fpr, tpr, color='darkorange', lw=2, marker='o', markersize=3 , label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()





from sklearn.metrics import precision_recall_curve, average_precision_score

# Calculate precision, recall, and threshold values
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_probs)

# Calculate the average precision
average_precision = average_precision_score(y_test, y_pred_probs)

# Plot the Precision-Recall curve
plt.figure(figsize=(3, 3))
plt.plot(recall, precision, color='darkorange', lw=2,marker='o', markersize=3, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="upper right")
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# ...
# Epoch 13: early stopping
# 9/9 [==============================] - 1s 23ms/step - loss: 1.7654 - accuracy: 0.9820
# Test loss: 1.7654409408569336
# Test accuracy: 0.9820144176483154
# 9/9 [==============================] - 0s 32ms/step - loss: 0.7190 - accuracy: 0.9928
# Validation loss: 0.7189788222312927
# Validation accuracy: 0.9928057789802551
# 9/9 [==============================] - 0s 20ms/step
#
#  Note Path | Predicted Label | Original Label
# ---------------------------------------------
#  E:/modified_dataset\fake_notes\note_135 | fake | fake
#  E:/modified_dataset\fake_notes\note_029 | fake | fake
#  E:/modified_dataset\fake_notes\note_317 | fake | fake
#  E:/modified_dataset\real_notes\note_289 | real | real
#  E:/modified_dataset\fake_notes\note_099 | fake | fake
#  E:/modified_dataset\real_notes\note_559 | real | real
#  E:/modified_dataset\fake_notes\note_463 | fake | fake
#  E:/modified_dataset\fake_notes\note_569 | fake | fake
#  E:/modified_dataset\fake_notes\note_454 | fake | fake
#  E:/modified_dataset\real_notes\note_376 | real | real
#  E:/modified_dataset\real_notes\note_358 | real | real
#  E:/modified_dataset\fake_notes\note_580 | fake | fake
#  E:/modified_dataset\real_notes\note_330 | real | real
#  E:/modified_dataset\real_notes\note_668 | real | real
#  E:/modified_dataset\real_notes\note_601 | real | real
#  E:/modified_dataset\fake_notes\note_137 | fake | fake
#  E:/modified_dataset\fake_notes\note_525 | fake | fake
#  E:/modified_dataset\fake_notes\note_062 | fake | fake
#  E:/modified_dataset\real_notes\note_171 | real | real
#  E:/modified_dataset\fake_notes\note_178 | fake | fake
#  E:/modified_dataset\real_notes\note_770 | real | real
#  E:/modified_dataset\real_notes\note_517 | real | real
#  E:/modified_dataset\fake_notes\note_045 | fake | fake
#  E:/modified_dataset\real_notes\note_442 | real | real
#  E:/modified_dataset\real_notes\note_406 | fake | real
#  E:/modified_dataset\fake_notes\note_189 | fake | fake
#  E:/modified_dataset\fake_notes\note_177 | fake | fake
#  E:/modified_dataset\real_notes\note_596 | real | real
#  E:/modified_dataset\fake_notes\note_034 | fake | fake
#  E:/modified_dataset\fake_notes\note_529 | fake | fake
#  E:/modified_dataset\fake_notes\note_056 | fake | fake
#  E:/modified_dataset\fake_notes\note_165 | fake | fake
#  E:/modified_dataset\real_notes\note_084 | real | real
#  E:/modified_dataset\fake_notes\note_146 | fake | fake
#  E:/modified_dataset\real_notes\note_689 | real | real
#  E:/modified_dataset\real_notes\note_433 | real | real
#  E:/modified_dataset\real_notes\note_500 | real | real
#  E:/modified_dataset\real_notes\note_380 | real | real
#  E:/modified_dataset\real_notes\note_650 | real | real
#  E:/modified_dataset\real_notes\note_716 | real | real
#  E:/modified_dataset\fake_notes\note_268 | fake | fake
#  E:/modified_dataset\fake_notes\note_306 | fake | fake
#  E:/modified_dataset\real_notes\note_070 | real | real
#  E:/modified_dataset\real_notes\note_341 | real | real
#  E:/modified_dataset\real_notes\note_774 | real | real
#  E:/modified_dataset\fake_notes\note_253 | fake | fake
#  E:/modified_dataset\fake_notes\note_156 | fake | fake
#  E:/modified_dataset\real_notes\note_747 | real | real
#  E:/modified_dataset\real_notes\note_343 | real | real
#  E:/modified_dataset\real_notes\note_471 | real | real
#  E:/modified_dataset\fake_notes\note_318 | fake | fake
#  E:/modified_dataset\real_notes\note_169 | real | real
#  E:/modified_dataset\real_notes\note_510 | real | real
#  E:/modified_dataset\fake_notes\note_170 | fake | fake
#  E:/modified_dataset\real_notes\note_646 | real | real
#  E:/modified_dataset\fake_notes\note_085 | fake | fake
#  E:/modified_dataset\real_notes\note_225 | real | real
#  E:/modified_dataset\fake_notes\note_314 | fake | fake
#  E:/modified_dataset\fake_notes\note_187 | fake | fake
#  E:/modified_dataset\real_notes\note_365 | real | real
#  E:/modified_dataset\real_notes\note_772 | real | real
#  E:/modified_dataset\real_notes\note_580 | real | real
#  E:/modified_dataset\real_notes\note_583 | real | real
#  E:/modified_dataset\real_notes\note_702 | real | real
#  E:/modified_dataset\real_notes\note_269 | real | real
#  E:/modified_dataset\fake_notes\note_393 | fake | fake
#  E:/modified_dataset\fake_notes\note_262 | fake | fake
#  E:/modified_dataset\real_notes\note_007 | real | real
#  E:/modified_dataset\real_notes\note_246 | real | real
#  E:/modified_dataset\real_notes\note_590 | real | real
#  E:/modified_dataset\real_notes\note_346 | real | real
#  E:/modified_dataset\real_notes\note_630 | real | real
#  E:/modified_dataset\fake_notes\note_250 | fake | fake
#  E:/modified_dataset\real_notes\note_691 | real | real
#  E:/modified_dataset\real_notes\note_378 | real | real
#  E:/modified_dataset\real_notes\note_211 | real | real
#  E:/modified_dataset\real_notes\note_431 | real | real
#  E:/modified_dataset\real_notes\note_427 | real | real
#  E:/modified_dataset\fake_notes\note_429 | fake | fake
#  E:/modified_dataset\fake_notes\note_032 | fake | fake
#  E:/modified_dataset\fake_notes\note_044 | fake | fake
#  E:/modified_dataset\real_notes\note_744 | real | real
#  E:/modified_dataset\fake_notes\note_570 | fake | fake
#  E:/modified_dataset\real_notes\note_743 | real | real
#  E:/modified_dataset\fake_notes\note_197 | fake | fake
#  E:/modified_dataset\fake_notes\note_201 | fake | fake
#  E:/modified_dataset\real_notes\note_799 | real | real
#  E:/modified_dataset\fake_notes\note_363 | fake | fake
#  E:/modified_dataset\fake_notes\note_236 | fake | fake
#  E:/modified_dataset\real_notes\note_118 | real | real
#  E:/modified_dataset\real_notes\note_672 | real | real
#  E:/modified_dataset\real_notes\note_033 | real | real
#  E:/modified_dataset\real_notes\note_121 | real | real
#  E:/modified_dataset\fake_notes\note_428 | fake | fake
#  E:/modified_dataset\real_notes\note_173 | real | real
#  E:/modified_dataset\fake_notes\note_207 | fake | fake
#  E:/modified_dataset\real_notes\note_093 | real | real
#  E:/modified_dataset\fake_notes\note_307 | fake | fake
#  E:/modified_dataset\fake_notes\note_376 | fake | fake
#  E:/modified_dataset\real_notes\note_424 | real | real
#  E:/modified_dataset\fake_notes\note_337 | fake | fake
#  E:/modified_dataset\fake_notes\note_347 | fake | fake
#  E:/modified_dataset\fake_notes\note_098 | fake | fake
#  E:/modified_dataset\fake_notes\note_335 | fake | fake
#  E:/modified_dataset\real_notes\note_166 | real | real
#  E:/modified_dataset\real_notes\note_663 | real | real
#  E:/modified_dataset\real_notes\note_483 | real | real
#  E:/modified_dataset\fake_notes\note_251 | fake | fake
#  E:/modified_dataset\real_notes\note_473 | real | real
#  E:/modified_dataset\real_notes\note_198 | real | real
#  E:/modified_dataset\real_notes\note_736 | real | real
#  E:/modified_dataset\real_notes\note_398 | real | real
#  E:/modified_dataset\fake_notes\note_185 | fake | fake
#  E:/modified_dataset\real_notes\note_568 | real | real
#  E:/modified_dataset\fake_notes\note_430 | fake | fake
#  E:/modified_dataset\real_notes\note_283 | real | real
#  E:/modified_dataset\real_notes\note_647 | real | real
#  E:/modified_dataset\real_notes\note_638 | real | real
#  E:/modified_dataset\real_notes\note_177 | real | real
#  E:/modified_dataset\real_notes\note_290 | real | real
#  E:/modified_dataset\fake_notes\note_357 | fake | fake
#  E:/modified_dataset\fake_notes\note_230 | fake | fake
#  E:/modified_dataset\real_notes\note_050 | real | real
#  E:/modified_dataset\fake_notes\note_458 | fake | fake
#  E:/modified_dataset\real_notes\note_083 | real | real
#  E:/modified_dataset\fake_notes\note_511 | fake | fake
#  E:/modified_dataset\real_notes\note_188 | real | real
#  E:/modified_dataset\fake_notes\note_498 | fake | fake
#  E:/modified_dataset\real_notes\note_210 | real | real
#  E:/modified_dataset\fake_notes\note_368 | fake | fake
#  E:/modified_dataset\fake_notes\note_022 | fake | fake
#  E:/modified_dataset\real_notes\note_162 | real | real
#  E:/modified_dataset\real_notes\note_539 | real | real
#  E:/modified_dataset\real_notes\note_235 | real | real
#  E:/modified_dataset\fake_notes\note_131 | fake | fake
#  E:/modified_dataset\real_notes\note_016 | real | real
#  E:/modified_dataset\fake_notes\note_091 | fake | fake
#  E:/modified_dataset\fake_notes\note_244 | fake | fake
#  E:/modified_dataset\real_notes\note_128 | real | real
#  E:/modified_dataset\fake_notes\note_066 | fake | fake
#  E:/modified_dataset\real_notes\note_575 | real | real
#  E:/modified_dataset\real_notes\note_262 | real | real
#  E:/modified_dataset\real_notes\note_095 | real | real
#  E:/modified_dataset\fake_notes\note_111 | real | fake
#  E:/modified_dataset\fake_notes\note_070 | fake | fake
#  E:/modified_dataset\real_notes\note_459 | real | real
#  E:/modified_dataset\fake_notes\note_512 | fake | fake
#  E:/modified_dataset\real_notes\note_544 | real | real
#  E:/modified_dataset\real_notes\note_247 | real | real
#  E:/modified_dataset\fake_notes\note_084 | fake | fake
#  E:/modified_dataset\fake_notes\note_199 | fake | fake
#  E:/modified_dataset\real_notes\note_642 | real | real
#  E:/modified_dataset\real_notes\note_267 | real | real
#  E:/modified_dataset\fake_notes\note_586 | fake | fake
#  E:/modified_dataset\real_notes\note_040 | real | real
#  E:/modified_dataset\fake_notes\note_513 | fake | fake
#  E:/modified_dataset\real_notes\note_039 | real | real
#  E:/modified_dataset\real_notes\note_737 | real | real
#  E:/modified_dataset\real_notes\note_028 | real | real
#  E:/modified_dataset\real_notes\note_238 | real | real
#  E:/modified_dataset\real_notes\note_387 | real | real
#  E:/modified_dataset\real_notes\note_242 | real | real
#  E:/modified_dataset\real_notes\note_140 | real | real
#  E:/modified_dataset\real_notes\note_240 | real | real
#  E:/modified_dataset\real_notes\note_013 | real | real
#  E:/modified_dataset\real_notes\note_043 | real | real
#  E:/modified_dataset\fake_notes\note_308 | fake | fake
#  E:/modified_dataset\real_notes\note_765 | real | real
#  E:/modified_dataset\real_notes\note_516 | real | real
#  E:/modified_dataset\real_notes\note_654 | real | real
#  E:/modified_dataset\real_notes\note_055 | real | real
#  E:/modified_dataset\fake_notes\note_276 | fake | fake
#  E:/modified_dataset\real_notes\note_487 | real | real
#  E:/modified_dataset\fake_notes\note_020 | fake | fake
#  E:/modified_dataset\real_notes\note_278 | real | real
#  E:/modified_dataset\fake_notes\note_261 | fake | fake
#  E:/modified_dataset\fake_notes\note_438 | fake | fake
#  E:/modified_dataset\real_notes\note_347 | real | real
#  E:/modified_dataset\real_notes\note_026 | real | real
#  E:/modified_dataset\real_notes\note_409 | real | real
#  E:/modified_dataset\real_notes\note_215 | real | real
#  E:/modified_dataset\real_notes\note_306 | real | real
#  E:/modified_dataset\real_notes\note_109 | real | real
#  E:/modified_dataset\real_notes\note_489 | real | real
#  E:/modified_dataset\fake_notes\note_179 | fake | fake
#  E:/modified_dataset\fake_notes\note_567 | fake | fake
#  E:/modified_dataset\real_notes\note_564 | real | real
#  E:/modified_dataset\real_notes\note_127 | real | real
#  E:/modified_dataset\fake_notes\note_518 | fake | fake
#  E:/modified_dataset\real_notes\note_154 | real | real
#  E:/modified_dataset\real_notes\note_796 | real | real
#  E:/modified_dataset\fake_notes\note_385 | fake | fake
#  E:/modified_dataset\real_notes\note_030 | real | real
#  E:/modified_dataset\real_notes\note_060 | real | real
#  E:/modified_dataset\real_notes\note_463 | real | real
#  E:/modified_dataset\fake_notes\note_548 | fake | fake
#  E:/modified_dataset\real_notes\note_610 | real | real
#  E:/modified_dataset\real_notes\note_037 | real | real
#  E:/modified_dataset\fake_notes\note_500 | fake | fake
#  E:/modified_dataset\real_notes\note_620 | real | real
#  E:/modified_dataset\fake_notes\note_058 | fake | fake
#  E:/modified_dataset\real_notes\note_779 | real | real
#  E:/modified_dataset\real_notes\note_107 | real | real
#  E:/modified_dataset\fake_notes\note_587 | fake | fake
#  E:/modified_dataset\real_notes\note_205 | real | real
#  E:/modified_dataset\fake_notes\note_382 | fake | fake
#  E:/modified_dataset\real_notes\note_260 | real | real
#  E:/modified_dataset\real_notes\note_795 | real | real
#  E:/modified_dataset\real_notes\note_593 | real | real
#  E:/modified_dataset\real_notes\note_145 | real | real
#  E:/modified_dataset\fake_notes\note_164 | fake | fake
#  E:/modified_dataset\fake_notes\note_352 | fake | fake
#  E:/modified_dataset\fake_notes\note_295 | fake | fake
#  E:/modified_dataset\real_notes\note_024 | real | real
#  E:/modified_dataset\fake_notes\note_477 | fake | fake
#  E:/modified_dataset\fake_notes\note_079 | fake | fake
#  E:/modified_dataset\real_notes\note_526 | real | real
#  E:/modified_dataset\real_notes\note_244 | real | real
#  E:/modified_dataset\real_notes\note_097 | real | real
#  E:/modified_dataset\fake_notes\note_110 | real | fake
#  E:/modified_dataset\real_notes\note_320 | real | real
#  E:/modified_dataset\fake_notes\note_014 | fake | fake
#  E:/modified_dataset\fake_notes\note_252 | fake | fake
#  E:/modified_dataset\real_notes\note_304 | real | real
#  E:/modified_dataset\fake_notes\note_129 | real | fake
#  E:/modified_dataset\real_notes\note_761 | real | real
#  E:/modified_dataset\real_notes\note_105 | real | real
#  E:/modified_dataset\fake_notes\note_290 | fake | fake
#  E:/modified_dataset\fake_notes\note_105 | fake | fake
#  E:/modified_dataset\fake_notes\note_109 | fake | fake
#  E:/modified_dataset\fake_notes\note_479 | fake | fake
#  E:/modified_dataset\fake_notes\note_246 | fake | fake
#  E:/modified_dataset\fake_notes\note_267 | fake | fake
#  E:/modified_dataset\fake_notes\note_521 | fake | fake
#  E:/modified_dataset\real_notes\note_588 | real | real
#  E:/modified_dataset\real_notes\note_653 | real | real
#  E:/modified_dataset\fake_notes\note_441 | fake | fake
#  E:/modified_dataset\real_notes\note_111 | real | real
#  E:/modified_dataset\real_notes\note_190 | real | real
#  E:/modified_dataset\real_notes\note_373 | real | real
#  E:/modified_dataset\real_notes\note_148 | real | real
#  E:/modified_dataset\fake_notes\note_530 | fake | fake
#  E:/modified_dataset\real_notes\note_514 | real | real
#  E:/modified_dataset\fake_notes\note_298 | fake | fake
#  E:/modified_dataset\fake_notes\note_258 | fake | fake
#  E:/modified_dataset\real_notes\note_151 | real | real
#  E:/modified_dataset\real_notes\note_695 | real | real
#  E:/modified_dataset\fake_notes\note_046 | fake | fake
#  E:/modified_dataset\fake_notes\note_410 | fake | fake
#  E:/modified_dataset\real_notes\note_597 | real | real
#  E:/modified_dataset\fake_notes\note_328 | fake | fake
#  E:/modified_dataset\real_notes\note_218 | real | real
#  E:/modified_dataset\real_notes\note_408 | real | real
#  E:/modified_dataset\fake_notes\note_293 | fake | fake
#  E:/modified_dataset\fake_notes\note_204 | fake | fake
#  E:/modified_dataset\fake_notes\note_388 | fake | fake
#  E:/modified_dataset\real_notes\note_701 | real | real
#  E:/modified_dataset\real_notes\note_192 | real | real
#  E:/modified_dataset\real_notes\note_565 | real | real
#  E:/modified_dataset\real_notes\note_446 | real | real
#  E:/modified_dataset\fake_notes\note_434 | fake | fake
#  E:/modified_dataset\real_notes\note_748 | real | real
#  E:/modified_dataset\real_notes\note_206 | real | real
#  E:/modified_dataset\fake_notes\note_502 | fake | fake
#  E:/modified_dataset\fake_notes\note_010 | fake | fake
#  E:/modified_dataset\real_notes\note_382 | real | real
#  E:/modified_dataset\fake_notes\note_319 | fake | fake
#  E:/modified_dataset\fake_notes\note_544 | fake | fake
#  E:/modified_dataset\real_notes\note_503 | real | real
#  E:/modified_dataset\real_notes\note_322 | real | real
#  E:/modified_dataset\real_notes\note_087 | real | real
#  E:/modified_dataset\real_notes\note_403 | fake | real
#  E:/modified_dataset\real_notes\note_448 | real | real
#  E:/modified_dataset\real_notes\note_587 | real | real
#  E:/modified_dataset\fake_notes\note_191 | fake | fake
#  E:/modified_dataset\fake_notes\note_037 | fake | fake
#  E:/modified_dataset\real_notes\note_789 | real | real
#  E:/modified_dataset\fake_notes\note_038 | fake | fake
# 9/9 [==============================] - 0s 22ms/step
# Precision: 0.98
# Recall: 0.97
# F1 score: 0.98
# 9/9 [==============================] - 0s 20ms/step

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.vgg16 import VGG16

def predict_note_type(model, note_path):
    img_size = (224, 224)
    img_channels = 3
    
    vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], img_channels))
    note_images = []
    for i in range(1, 7):
        image_path = os.path.join(note_path, f'{note_path.split("/")[-1]}_{i}.jpg')
        print(f"Loading image: {image_path}")
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error loading image: {image_path}")
        note_images.append(image)
    
    preprocessed_images = []
    for image in note_images:
        image = cv2.resize(image, img_size)
        image = preprocess_input(image)
        image_features = vgg16_model.predict(np.expand_dims(image, axis=0))
        preprocessed_images.append(image_features.reshape((1, 7, 7, 512)))
    
    X_features = np.concatenate(preprocessed_images, axis=0)
    X_features = X_features.reshape((1, 6, 7, 7, 512))

    # Load the saved model
      

    # Make predictions on the input images
    y_pred = model.predict(X_features)
    y_pred_binary = (y_pred > 0.5).astype(int)
    return y_pred_binary[0][0]

note_path = 'E:/modified_dataset/fake_notes/note_406'
model = load_model('E:/my_model/vgg16_model.h5')
model.summary()
result = predict_note_type(model, note_path)
if result == 0:
    print("Your note is real")
else:
    print("Your note is fake")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 6, 7, 7, 51  0           []
#                                 2)]
#
#  lambda (Lambda)                [(None, 7, 7, 512),  0           ['input_2[0][0]']
#                                  (None, 7, 7, 512),
#                                  (None, 7, 7, 512),
#                                  (None, 7, 7, 512),
#                                  (None, 7, 7, 512),
#                                  (None, 7, 7, 512)]
#
#  flatten (Flatten)              (None, 25088)        0           ['lambda[0][0]']
#
#  flatten_1 (Flatten)            (None, 25088)        0           ['lambda[0][1]']
#
#  flatten_2 (Flatten)            (None, 25088)        0           ['lambda[0][2]']
#
#  flatten_3 (Flatten)            (None, 25088)        0           ['lambda[0][3]']
#
#  flatten_4 (Flatten)            (None, 25088)        0           ['lambda[0][4]']
#
#  flatten_5 (Flatten)            (None, 25088)        0           ['lambda[0][5]']
#
#  concatenate (Concatenate)      (None, 150528)       0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'flatten_3[0][0]',
#                                                                   'flatten_4[0][0]',
#                                                                   'flatten_5[0][0]']
#
#  dropout (Dropout)              (None, 150528)       0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 64)           9633856     ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            65          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 9,633,921
# Trainable params: 9,633,921
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_1.jpg
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_2.jpg
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_3.jpg
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_4.jpg
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_5.jpg
# Loading image: E:/modified_dataset/fake_notes/note_406\note_406_6.jpg
# 1/1 [==============================] - 1s 651ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 146ms/step
# Your note is fake
